# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
df=pd.read_csv("smart loan tracker.csv")
df.head()
# Out:
#    Loan ID      Loan Type  Loan Amount (INR)  Interest Rate (%)  Start Date  \
# 0     1001  Personal Loan           500000.0                5.5  2023-01-10
# 1     1002       Car Loan          1500000.0                4.0  2023-03-15
# 2     1003      Home Loan         12000000.0                3.5  2022-06-01
# 3     1004   Student Loan          2500000.0                6.0  2021-09-01
# 4     1005  Business Loan          5000000.0                7.0  2024-01-01
#
#      Due Date  Outstanding Balance (INR) Payment Status Last Payment Date  \
# 0  2025-01-10                   320000.0       On Track        2024-01-03
# 1  2026-03-15                  1050000.0       On Track        2024-02-08
# 2  2042-06-01                 11500000.0       On Track        2023-12-25
# 3  2031-09-01                  2000000.0   Late Payment        2023-11-10
# 4  2029-01-01                  5000000.0    Not Started               NaN
#
#    Amount Paid (INR) Next Reminder Date
# ...

# %%
df=pd.read_csv("smart loan tracker.csv")
df.corr(numeric_only=True)
# Out:
#                             Loan ID  Loan Amount (INR)  Interest Rate (%)  \
# Loan ID                    1.000000           0.032731           0.161613
# Loan Amount (INR)          0.032731           1.000000          -0.365000
# Interest Rate (%)          0.161613          -0.365000           1.000000
# Outstanding Balance (INR)  0.043842           0.999168          -0.340842
# Amount Paid (INR)          0.038198           0.742332          -0.734435
#
#                            Outstanding Balance (INR)  Amount Paid (INR)
# Loan ID                                     0.043842           0.038198
# Loan Amount (INR)                           0.999168           0.742332
# Interest Rate (%)                          -0.340842          -0.734435
# Outstanding Balance (INR)                   1.000000           0.726156
# Amount Paid (INR)                           0.726156           1.000000

# %%
print('DF Shape: ', df.shape)
# Out:
# DF Shape:  (21, 11)

# %%
print(' DATASET:')
print(df.info())
# Out:
#  DATASET:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Loan ID                    21 non-null     int64
#  1   Loan Type                  21 non-null     object
#  2   Loan Amount (INR)          21 non-null     float64
#  3   Interest Rate (%)          21 non-null     float64
#  4   Start Date                 21 non-null     object
#  5   Due Date                   21 non-null     object
#  6   Outstanding Balance (INR)  21 non-null     float64
#  7   Payment Status             21 non-null     object
#  8   Last Payment Date          17 non-null     object
#  9   Amount Paid (INR)          20 non-null     float64
#  10  Next Reminder Date         20 non-null     object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 1.9+ KB
# None

# %%
df.columns.values.tolist()
# Out:
# ['Loan ID',
#  'Loan Type',
#  'Loan Amount (INR)',
#  'Interest Rate (%)',
#  'Start Date',
#  'Due Date',
#  'Outstanding Balance (INR)',
#  'Payment Status',
#  'Last Payment Date',
#  'Amount Paid (INR)',
#  'Next Reminder Date']

# %%
d = df.describe() 
display(d)
# Out:
#            Loan ID  Loan Amount (INR)  Interest Rate (%)  \
# count    21.000000       2.100000e+01          21.000000
# mean   1011.000000       4.397619e+06           5.304762
# std       6.204837       4.185346e+06           1.500825
# min    1001.000000       5.000000e+05           3.000000
# 25%    1006.000000       1.500000e+06           3.900000
# 50%    1011.000000       2.700000e+06           5.600000
# 75%    1016.000000       6.000000e+06           6.500000
# max    1021.000000       1.500000e+07           7.500000
#
#        Outstanding Balance (INR)  Amount Paid (INR)
# count               2.100000e+01          20.000000
# mean                4.172381e+06       38650.000000
# std                 4.085888e+06       34353.081529
# min                 3.200000e+05           0.000000
# 25%                 1.100000e+06       17250.000000
# 50%                 2.430000e+06       35000.000000
# 75%                 6.000000e+06       46250.000000
# ...

# %%
correlation_matrix = df[["Loan ID","Interest Rate (%)","Loan Amount (INR)","Outstanding Balance (INR)","Amount Paid (INR)"]].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='Reds')
plt.show()

# %%
plt.figure(figsize=(6,6))
df[["Loan Type"]].value_counts().plot(kind='bar',color='red') 
plt.show()

# %%
plt.figure(figsize=(6,6))
df[["Payment Status"]].value_counts().plot(kind='bar',color='red') 
plt.show()
